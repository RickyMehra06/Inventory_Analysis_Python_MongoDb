# %%
import pandas as pd
import os, glob
from datetime import date,timedelta
import random
import numpy as np
import pymongo
import json

import warnings
warnings.filterwarnings('ignore')

DATABASE_NAME = "Invetory_db"
COLLECTION_NAME ="Invetory_collection"

# %%
import getpass

user_id = getpass.getpass(prompt="Enter MongoDB user ID: ")
password = getpass.getpass(prompt="Enter MongoDB password: ")

mongo_client = pymongo.MongoClient(f"mongodb+srv://{user_id}:{password}@cluster0.gseurtj.mongodb.net/?retryWrites=true&w=majority")
# Out:
# Enter MongoDB user ID: ········
# Enter MongoDB password: ········

# %%
# Reading data from MongoDb

df = pd.DataFrame(list(mongo_client[DATABASE_NAME][COLLECTION_NAME].find()))
            
if "_id" in df.columns:
    df.drop("_id", axis=1, inplace=True)
print(df.shape)
# Out:
# (52276, 7)

# %%
df = df.sort_values(by=['ISBN','Date',], ascending=False)

# %%
print(df["Date"].min())
print(df["Date"].max())
# Out:
# 2022-11-29 00:00:00
# 2023-03-28 00:00:00

# %%
df["Unit_Sold"] = df["QTY"].diff(1)
df.head(10)
# Out:
#                     ISBN                   Name  Price Publisher  QTY  \
# 7193   978-1-9991865-1-7  Happy religious tell.    900      IBBD   11
# 7313   978-1-9991865-1-7  Happy religious tell.    900      IBBD   29
# 8058   978-1-9991865-1-7  Happy religious tell.    900      IBBD   66
# 8421   978-1-9991865-1-7  Happy religious tell.    900      IBBD   87
# 8730   978-1-9991865-1-7  Happy religious tell.    900      IBBD  134
# 9590   978-1-9991865-1-7  Happy religious tell.    900      IBBD  138
# 9923   978-1-9991865-1-7  Happy religious tell.    900      IBBD  152
# 10783  978-1-9991865-1-7  Happy religious tell.    900      IBBD  225
# 11857  978-1-9991865-1-7  Happy religious tell.    900      IBBD  268
# 12452  978-1-9991865-1-7  Happy religious tell.    900      IBBD  296
#
#             Date        Day  Unit_Sold
# 7193  2023-03-06     Monday        NaN
# 7313  2023-03-04   Saturday       18.0
# 8058  2023-03-03     Friday       37.0
# 8421  2023-03-02   Thursday       21.0
# 8730  2023-03-01  Wednesday       47.0
# 9590  2023-02-28    Tuesday        4.0
# 9923  2023-02-27     Monday       14.0
# 10783 2023-02-25   Saturday       73.0
# 11857 2023-02-24     Friday       43.0
# 12452 2023-02-23   Thursday       28.0

# %%
# Dropping current day values cos we do not have details how many quantity will be sold today at the starting of the day
df.dropna(subset=['Unit_Sold'], inplace=True)
df.drop(df.loc[df['Date']==df['Date'].max()].index, inplace=True)
df["Unit_Sold"]= df["Unit_Sold"].astype('int')
df.reset_index(inplace=True, drop=True)
df.head(10)
# Out:
#                 ISBN                   Name  Price Publisher  QTY       Date  \
# 0  978-1-9991865-1-7  Happy religious tell.    900      IBBD   29 2023-03-04
# 1  978-1-9991865-1-7  Happy religious tell.    900      IBBD   66 2023-03-03
# 2  978-1-9991865-1-7  Happy religious tell.    900      IBBD   87 2023-03-02
# 3  978-1-9991865-1-7  Happy religious tell.    900      IBBD  134 2023-03-01
# 4  978-1-9991865-1-7  Happy religious tell.    900      IBBD  138 2023-02-28
# 5  978-1-9991865-1-7  Happy religious tell.    900      IBBD  152 2023-02-27
# 6  978-1-9991865-1-7  Happy religious tell.    900      IBBD  225 2023-02-25
# 7  978-1-9991865-1-7  Happy religious tell.    900      IBBD  268 2023-02-24
# 8  978-1-9991865-1-7  Happy religious tell.    900      IBBD  296 2023-02-23
# 9  978-1-9991865-1-7  Happy religious tell.    900      IBBD  342 2023-02-22
#
#          Day  Unit_Sold
# 0   Saturday         18
# 1     Friday         37
# 2   Thursday         21
# 3  Wednesday         47
# 4    Tuesday          4
# 5     Monday         14
# 6   Saturday         73
# 7     Friday         43
# 8   Thursday         28
# 9  Wednesday         46

# %%
df["Restocked_Days"] = df["Date"].diff(-1)
df.dropna(inplace= True)
df.reset_index(inplace=True, drop=True)

df["Restocked_Days"] = df["Restocked_Days"].dt.days.astype('int')
df["Restocked_Days"].loc[df["Restocked_Days"]<=0] = 1
df.head(25)
# Out:
#                  ISBN                   Name  Price Publisher  QTY       Date  \
# 0   978-1-9991865-1-7  Happy religious tell.    900      IBBD   29 2023-03-04
# 1   978-1-9991865-1-7  Happy religious tell.    900      IBBD   66 2023-03-03
# 2   978-1-9991865-1-7  Happy religious tell.    900      IBBD   87 2023-03-02
# 3   978-1-9991865-1-7  Happy religious tell.    900      IBBD  134 2023-03-01
# 4   978-1-9991865-1-7  Happy religious tell.    900      IBBD  138 2023-02-28
# 5   978-1-9991865-1-7  Happy religious tell.    900      IBBD  152 2023-02-27
# 6   978-1-9991865-1-7  Happy religious tell.    900      IBBD  225 2023-02-25
# 7   978-1-9991865-1-7  Happy religious tell.    900      IBBD  268 2023-02-24
# 8   978-1-9991865-1-7  Happy religious tell.    900      IBBD  296 2023-02-23
# 9   978-1-9991865-1-7  Happy religious tell.    900      IBBD  342 2023-02-22
# 10  978-1-9991865-1-7  Happy religious tell.    900      IBBD  359 2023-02-21
# 11  978-1-9991865-1-7  Happy religious tell.    900      IBBD  401 2023-02-20
# 12  978-1-9991865-1-7  Happy religious tell.    900      IBBD  469 2023-02-18
# 13  978-1-9991865-1-7  Happy religious tell.    900      IBBD  500 2023-02-17
# 14  978-1-9991865-1-7  Happy religious tell.    900      IBBD   27 2023-01-27
# 15  978-1-9991865-1-7  Happy religious tell.    900      IBBD   62 2023-01-26
# 16  978-1-9991865-1-7  Happy religious tell.    900      IBBD   97 2023-01-25
# 17  978-1-9991865-1-7  Happy religious tell.    900      IBBD   98 2023-01-24
# 18  978-1-9991865-1-7  Happy religious tell.    900      IBBD  145 2023-01-23
# 19  978-1-9991865-1-7  Happy religious tell.    900      IBBD  227 2023-01-21
# 20  978-1-9991865-1-7  Happy religious tell.    900      IBBD  234 2023-01-20
# 21  978-1-9991865-1-7  Happy religious tell.    900      IBBD  281 2023-01-19
# 22  978-1-9991865-1-7  Happy religious tell.    900      IBBD  312 2023-01-18
# 23  978-1-9991865-1-7  Happy religious tell.    900      IBBD  361 2023-01-17
# 24  978-1-9991865-1-7  Happy religious tell.    900      IBBD  411 2023-01-16
#
#           Day  Unit_Sold  Restocked_Days
# 0    Saturday         18               1
# 1      Friday         37               1
# 2    Thursday         21               1
# 3   Wednesday         47               1
# 4     Tuesday          4               1
# 5      Monday         14               2
# 6    Saturday         73               1
# 7      Friday         43               1
# 8    Thursday         28               1
# 9   Wednesday         46               1
# 10    Tuesday         17               1
# 11     Monday         42               2
# 12   Saturday         68               1
# 13     Friday         31              21
# 14     Friday       -473               1
# 15   Thursday         35               1
# 16  Wednesday         35               1
# 17    Tuesday          1               1
# 18     Monday         47               2
# 19   Saturday         82               1
# 20     Friday          7               1
# 21   Thursday         47               1
# 22  Wednesday         31               1
# 23    Tuesday         49               1
# 24     Monday         50               2

# %%
df["Status"] = ""

df.Status.loc[(df['Unit_Sold'] > 0)]   = "Available" 
df.Status.loc[(df['Unit_Sold'] < 0)]   = "Sold Out"
df.Status.loc[(df['Unit_Sold'] == 0)]  = "No Sale"
df.Status.loc[(df['Restocked_Days']>2)]= "Restocked" 
df.head(25)
# Out:
#                  ISBN                   Name  Price Publisher  QTY       Date  \
# 0   978-1-9991865-1-7  Happy religious tell.    900      IBBD   29 2023-03-04
# 1   978-1-9991865-1-7  Happy religious tell.    900      IBBD   66 2023-03-03
# 2   978-1-9991865-1-7  Happy religious tell.    900      IBBD   87 2023-03-02
# 3   978-1-9991865-1-7  Happy religious tell.    900      IBBD  134 2023-03-01
# 4   978-1-9991865-1-7  Happy religious tell.    900      IBBD  138 2023-02-28
# 5   978-1-9991865-1-7  Happy religious tell.    900      IBBD  152 2023-02-27
# 6   978-1-9991865-1-7  Happy religious tell.    900      IBBD  225 2023-02-25
# 7   978-1-9991865-1-7  Happy religious tell.    900      IBBD  268 2023-02-24
# 8   978-1-9991865-1-7  Happy religious tell.    900      IBBD  296 2023-02-23
# 9   978-1-9991865-1-7  Happy religious tell.    900      IBBD  342 2023-02-22
# 10  978-1-9991865-1-7  Happy religious tell.    900      IBBD  359 2023-02-21
# 11  978-1-9991865-1-7  Happy religious tell.    900      IBBD  401 2023-02-20
# 12  978-1-9991865-1-7  Happy religious tell.    900      IBBD  469 2023-02-18
# 13  978-1-9991865-1-7  Happy religious tell.    900      IBBD  500 2023-02-17
# 14  978-1-9991865-1-7  Happy religious tell.    900      IBBD   27 2023-01-27
# 15  978-1-9991865-1-7  Happy religious tell.    900      IBBD   62 2023-01-26
# 16  978-1-9991865-1-7  Happy religious tell.    900      IBBD   97 2023-01-25
# 17  978-1-9991865-1-7  Happy religious tell.    900      IBBD   98 2023-01-24
# 18  978-1-9991865-1-7  Happy religious tell.    900      IBBD  145 2023-01-23
# 19  978-1-9991865-1-7  Happy religious tell.    900      IBBD  227 2023-01-21
# 20  978-1-9991865-1-7  Happy religious tell.    900      IBBD  234 2023-01-20
# 21  978-1-9991865-1-7  Happy religious tell.    900      IBBD  281 2023-01-19
# 22  978-1-9991865-1-7  Happy religious tell.    900      IBBD  312 2023-01-18
# 23  978-1-9991865-1-7  Happy religious tell.    900      IBBD  361 2023-01-17
# 24  978-1-9991865-1-7  Happy religious tell.    900      IBBD  411 2023-01-16
#
#           Day  Unit_Sold  Restocked_Days     Status
# 0    Saturday         18               1  Available
# 1      Friday         37               1  Available
# 2    Thursday         21               1  Available
# 3   Wednesday         47               1  Available
# 4     Tuesday          4               1  Available
# 5      Monday         14               2  Available
# 6    Saturday         73               1  Available
# 7      Friday         43               1  Available
# 8    Thursday         28               1  Available
# 9   Wednesday         46               1  Available
# 10    Tuesday         17               1  Available
# 11     Monday         42               2  Available
# 12   Saturday         68               1  Available
# 13     Friday         31              21  Restocked
# 14     Friday         27               1   Sold Out
# 15   Thursday         35               1  Available
# 16  Wednesday         35               1  Available
# 17    Tuesday          1               1  Available
# 18     Monday         47               2  Available
# 19   Saturday         82               1  Available
# 20     Friday          7               1  Available
# 21   Thursday         47               1  Available
# 22  Wednesday         31               1  Available
# 23    Tuesday         49               1  Available
# 24     Monday         50               2  Available

# %%
df["Status"].unique()
# Out:
# array(['Available', 'Restocked', 'Sold Out', 'No Sale'], dtype=object)

# %%
df["Date"].max()
# Out:
# Timestamp('2023-03-27 00:00:00')

# %%
latest_data = df[df["Date"]==df["Date"].max()]
latest_data
# Out:
#                     ISBN                                               Name  \
# 47     978-1-996801-16-1                 Girl animal street put game spend.
# 152    978-1-995467-16-0                           Yourself score interest.
# 296    978-1-992817-45-6  Various tend owner remember involve matter space.
# 350    978-1-991541-20-8                         Interest religious mother.
# 402    978-1-991019-10-3     Success significant pull finish move discover.
# ...                  ...                                                ...
# 51075  978-0-02-154686-2                                    Day off artist.
# 51239  978-0-01-572408-5                  Least four executive effort only.
# 51288  978-0-01-388849-9                             Mind both same report.
# 51333  978-0-01-049510-2                                   Never among now.
# 51388  978-0-00-652301-7                   Around early not myself himself.
#
#        Price Publisher  QTY       Date     Day  Unit_Sold  Restocked_Days  \
# 47       500      Amex  458 2023-03-27  Monday         36               2
# 152      100      IBBD  359 2023-03-27  Monday         34               2
# 296      300      IBBD  213 2023-03-27  Monday         12               2
# 350      800    Osprey  242 2023-03-27  Monday         48               2
# 402      600      IBBD  154 2023-03-27  Monday         11               2
# ...      ...       ...  ...        ...     ...        ...             ...
# 51075    800       RBC  203 2023-03-27  Monday          8               2
# 51239   1000     Rappa  466 2023-03-27  Monday         34              23
# 51288    500       WBC  372 2023-03-27  Monday          7               2
# 51333    100    Osprey  278 2023-03-27  Monday         31               2
# 51388    400      IBBD  312 2023-03-27  Monday         30               2
#
#           Status
# 47     Available
# 152    Available
# 296    Available
# 350    Available
# 402    Available
# ...          ...
# 51075  Available
# 51239  Restocked
# 51288  Available
# 51333  Available
# 51388  Available
#
# [707 rows x 10 columns]

# %%
# Top selling 5 ISBN of each Publisher

top_selling_data = latest_data.sort_values(['Publisher', 'Unit_Sold'],ascending=False).groupby('Publisher').head(5)
top_selling_data
# Out:
#                     ISBN                                            Name  \
# 17901  978-1-325-95471-1                         Movement start kitchen.
# 43720  978-0-314-25143-5                        Support open spend hour.
# 27036  978-0-9721453-6-7                               Until three fill.
# 20289  978-1-240-84646-7              Old wait age much toward resource.
# 49741  978-0-06-281360-2            Impact indicate forward prove thank.
# 6036   978-1-77658-202-0                She open discussion interesting.
# 13699  978-1-4934-9719-5               Generation institution than cell.
# 13806  978-1-4899-8156-1                       This community character.
# 23843  978-1-109-10886-6                           Fear nor common past.
# 25546  978-1-02-504153-7   Brother too challenge evidence design player.
# 3962   978-1-86225-767-2                Door message billion five small.
# 18306  978-1-306-87048-1                     Up loss peace let star get.
# 10793  978-1-60083-958-0                            Manager same relate.
# 47261  978-0-17-757386-6                     Wide agent they Republican.
# 1406   978-1-954557-90-1               Their total teach set difference.
# 12365  978-1-5340-5401-1                              Meet say whatever.
# 28444  978-0-920587-40-9               Believe college sign water still.
# 35962  978-0-626-61387-7                         Option draw commercial.
# 39188  978-0-519-40259-5               Thought should agreement partner.
# 15462  978-1-4191-3395-4                Better rise movement ready vote.
# 37743  978-0-563-69570-7                        Value body quite detail.
# 6083   978-1-77208-607-2              College area very manager century.
# 7615   978-1-71027-024-2        Forward they participant join something.
# 30997  978-0-8144-6203-4        Clearly candidate situation focus early.
# 7716   978-1-70799-820-3              Sport although yourself religious.
# 10736  978-1-60571-597-1                      Person now election short.
# 32242  978-0-7651-1695-6                  At finally rich lose consumer.
# 350    978-1-991541-20-8                      Interest religious mother.
# 13594  978-1-4965-7792-4                Staff deep team low argue stand.
# 11159  978-1-59033-819-3                          Build base nice focus.
# 10488  978-1-61273-265-7                              Personal huge sit.
# 20237  978-1-244-07888-8                          Available night speak.
# 30846  978-0-8237-6365-8                   Military likely relationship.
# 49141  978-0-09-654197-7                            Condition really or.
# 7665   978-1-70864-879-4                              Would likely data.
# 9883   978-1-62896-932-0                              South build media.
# 28700  978-0-907185-50-5             Poor them key capital company east.
# 36065  978-0-622-84796-2              Detail explain than character for.
# 34255  978-0-690-24921-7                    Available game student head.
# 40817  978-0-451-54642-5                         What Democrat American.
# 34306  978-0-690-09584-5                Who decision capital be herself.
# 9626   978-1-64154-345-3          Work remember every quality day again.
# 21371  978-1-201-34408-7                           Its ago culture save.
# 20652  978-1-232-60841-7                  Station tax say program avoid.
# 45953  978-0-212-04879-3           Onto term property religious serious.
# 19255  978-1-282-04679-5  Doctor job answer present face responsibility.
# 20137  978-1-245-72670-2                           Under Democrat every.
# 33586  978-0-7116-2500-6                      Drive answer always sport.
# 50873  978-0-02-824820-2                                 See week quite.
# 3752   978-1-86577-051-2                   After sort provide pick help.
#
#        Price Publisher  QTY       Date     Day  Unit_Sold  Restocked_Days  \
# 17901    700       WBC  427 2023-03-27  Monday         50               2
# 43720    200       WBC  426 2023-03-27  Monday         49               2
# 27036    700       WBC  384 2023-03-27  Monday         48               2
# 20289   1000       WBC  376 2023-03-27  Monday         45               2
# 49741    400       WBC  418 2023-03-27  Monday         45               2
# 11159  Available
# 10488  Available
# 20237  Available
# 30846  Available
# 49141  Available
# 7665   Available
# 9883   Available
# 28700  Restocked
# 36065  Available
# 34255  Available
# 40817  Available
# 34306  Restocked
# 9626   Restocked
# 21371  Available
# 20652  Available
# 45953  Available
# 19255  Available
# 20137  Restocked
# 33586  Available
# 50873  Available
# 3752   Available

# %%
path_dir = os.path.join(os.getcwd(), "ISBN_Inventory")
os.makedirs(path_dir, exist_ok=True)
file_path = os.path.join(path_dir, "Top_Selling_Data.xlsx")
                         
top_selling_data.to_excel(file_path, header=True, index=False)

# %%
summary = pd.DataFrame()

summary['Total_Sold'] = df["Unit_Sold"].groupby(df["ISBN"]).sum()

summary['Max_qty_sold'] = df["Unit_Sold"].groupby(df["ISBN"]).max()
summary['Min_qty_sold'] = df["Unit_Sold"].groupby(df["ISBN"]).min()
summary['Ave_Sold'] = round(df["Unit_Sold"].groupby(df["ISBN"]).mean())

summary['Max_Restock_days'] = df["Restocked_Days"].groupby(df["ISBN"]).max()
summary['Min_Restock_days'] = df["Restocked_Days"][df["Restocked_Days"]>2].groupby(df["ISBN"]).min()
summary
# Out:
#                    Total_Sold  Max_qty_sold  Min_qty_sold  Ave_Sold  \
# ISBN
# 978-0-00-046359-3        1271            64             0      25.0
# 978-0-00-409198-3        1333            54             0      24.0
# 978-0-00-652301-7        1528            88             0      31.0
# 978-0-01-049510-2        1521            65             1      28.0
# 978-0-01-388849-9        1385            92             1      31.0
# ...                       ...           ...           ...       ...
# 978-1-994588-91-0        1388            90             0      28.0
# 978-1-995467-16-0        1655            74             0      30.0
# 978-1-996753-53-8        1428            59             3      27.0
# 978-1-996801-16-1        1232            58             0      23.0
# 978-1-9991865-1-7        1434            82             1      31.0
#
#                    Max_Restock_days  Min_Restock_days
# ISBN
# 978-0-00-046359-3                21                19
# 978-0-00-409198-3                24                19
# 978-0-00-652301-7                26                19
# 978-0-01-049510-2                20                18
# 978-0-01-388849-9                24                22
# ...                             ...               ...
# 978-1-994588-91-0                23                20
# 978-1-995467-16-0                23                18
# 978-1-996753-53-8                24                23
# 978-1-996801-16-1                22                19
# 978-1-9991865-1-7                24                21
#
# [1000 rows x 6 columns]

# %%
summary.insert(loc=0, column='ISBN', value=summary.index)
summary.reset_index(inplace=True, drop=True)
summary.head()
# Out:
#                 ISBN  Total_Sold  Max_qty_sold  Min_qty_sold  Ave_Sold  \
# 0  978-0-00-046359-3        1271            64             0      25.0
# 1  978-0-00-409198-3        1333            54             0      24.0
# 2  978-0-00-652301-7        1528            88             0      31.0
# 3  978-0-01-049510-2        1521            65             1      28.0
# 4  978-0-01-388849-9        1385            92             1      31.0
#
#    Max_Restock_days  Min_Restock_days
# 0                21                19
# 1                24                19
# 2                26                19
# 3                20                18
# 4                24                22

# %%
path_dir = os.path.join(os.getcwd(), "ISBN_Inventory")
os.makedirs(path_dir, exist_ok=True)
file_path = os.path.join(path_dir, "ISBN_summary.xlsx")
                         
summary.to_excel(file_path, header=True, index=False)
